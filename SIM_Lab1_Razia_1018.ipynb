# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Sample scalar and array inputs
scalar = 3.7
arr = np.array([4,6,9,-3,2,1])

# Trigonometric functions
sin_values = np.sin(arr)
cos_values = np.cos(arr)
tan_values = np.tan(arr)
asin_values = np.arcsin(np.clip(arr / np.max(arr), -1, 1))  # Normalized and Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(arr / np.max(arr), -1, 1))
atan_values = np.arctan(arr)

# Exponential and logarithm
exp_values = np.exp(arr)
log_values = np.log(arr)  # Natural logarithm

# Absolute value and square root
abs_values = np.abs(arr)
sqrt_values = np.sqrt(arr)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(arr, 2)

# Rounding functions
round_values = np.round(arr)
floor_values = np.floor(arr)
ceil_values = np.ceil(arr)

# Display results
print("sin:", sin_values)
print("cos:", cos_values)
print("tan:", tan_values)
print("asin:", asin_values)
print("acos:", acos_values)
print("atan:", atan_values)
print("exp:", exp_values)
print("log:", log_values)
print("abs:", abs_values)
print("sqrt:", sqrt_values)
print("rem:", rem_values)
print("round:", round_values)
print("floor:", floor_values)
print("ceil:", ceil_values)
# Out:
# sin: [-0.7568025  -0.2794155   0.41211849 -0.14112001  0.90929743  0.84147098]
# cos: [-0.65364362  0.96017029 -0.91113026 -0.9899925  -0.41614684  0.54030231]
# tan: [ 1.15782128 -0.29100619 -0.45231566  0.14254654 -2.18503986  1.55740772]
# asin: [ 0.46055399  0.72972766  1.57079633 -0.33983691  0.22409309  0.11134101]
# acos: [1.11024234 0.84106867 0.         1.91063324 1.34670323 1.45945531]
# atan: [ 1.32581766  1.40564765  1.46013911 -1.24904577  1.10714872  0.78539816]
# exp: [5.45981500e+01 4.03428793e+02 8.10308393e+03 4.97870684e-02
#  7.38905610e+00 2.71828183e+00]
# log: [1.38629436 1.79175947 2.19722458        nan 0.69314718 0.        ]
# abs: [4 6 9 3 2 1]
# sqrt: [2.         2.44948974 3.                nan 1.41421356 1.        ]
# rem: [0 0 1 1 0 1]
# round: [ 4  6  9 -3  2  1]
# floor: [ 4.  6.  9. -3.  2.  1.]
# ceil: [ 4.  6.  9. -3.  2.  1.]
# /tmp/ipykernel_1938/1553685549.py:19: RuntimeWarning: invalid value encountered in log
#   log_values = np.log(arr)  # Natural logarithm
# /tmp/ipykernel_1938/1553685549.py:23: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_values = np.sqrt(arr)

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Creating a 3x2 matrix
matrix = np.array([[9, 2],[-8,7], [5, -1]])

# Trigonometric functions
sin_values = np.sin(matrix)
cos_values = np.cos(matrix)
tan_values = np.tan(matrix)
asin_values = np.arcsin(np.clip(matrix / np.max(matrix), -1, 1))  # Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(matrix / np.max(matrix), -1, 1))
atan_values = np.arctan(matrix)

# Exponential and logarithm
exp_values = np.exp(matrix)
log_values = np.log(matrix)  # Natural logarithm (log base e)

# Absolute value and square root
abs_values = np.abs(matrix)
sqrt_values = np.sqrt(matrix)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(matrix, 2)

# Rounding functions
round_values = np.round(matrix)
floor_values = np.floor(matrix)
ceil_values = np.ceil(matrix)

# Display results
print("Matrix:\n", matrix)
print("\nsin:\n", sin_values)
print("\ncos:\n", cos_values)
print("\ntan:\n", tan_values)
print("\nasine:\n", asin_values)
print("\nacosine:\n", acos_values)
print("\natangent:\n", atan_values)
print("\nexp:\n", exp_values)
print("\nlog (natural):\n", log_values)
print("\nabs:\n", abs_values)
print("\nsqrt:\n", sqrt_values)
print("\nrem (remainder when divided by 2):\n", rem_values)
print("\nround:\n", round_values)
print("\nfloor:\n", floor_values)
print("\nceil:\n", ceil_values)
# Out:
# Matrix:
#  [[ 9  2]
#  [-8  7]
#  [ 5 -1]]
#
# sin:
#  [[ 0.41211849  0.90929743]
#  [-0.98935825  0.6569866 ]
#  [-0.95892427 -0.84147098]]
#
# cos:
#  [[-0.91113026 -0.41614684]
#  [-0.14550003  0.75390225]
#  [ 0.28366219  0.54030231]]
#
# tan:
#  [[-0.45231566 -2.18503986]
#  [ 6.79971146  0.87144798]
#  [-3.38051501 -1.55740772]]
#
# asine:
#  [[ 1.57079633  0.22409309]
#  [-1.09491408  0.89112251]
#  [ 0.58903097 -0.11134101]]
#
# acosine:
#  [[0.         1.34670323]
#  [2.6657104  0.67967382]
#  [0.98176536 1.68213734]]
#
# atangent:
#  [[ 1.46013911  1.10714872]
#  [-1.44644133  1.42889927]
#  [ 1.37340077 -0.78539816]]
#
# exp:
#  [[8.10308393e+03 7.38905610e+00]
#  [3.35462628e-04 1.09663316e+03]
#  [1.48413159e+02 3.67879441e-01]]
#
# log (natural):
#  [[2.19722458 0.69314718]
#  [       nan 1.94591015]
#  [1.60943791        nan]]
#
# abs:
#  [[9 2]
#  [8 7]
#  [5 1]]
#
# sqrt:
#  [[3.         1.41421356]
#  [       nan 2.64575131]
#  [2.23606798        nan]]
#
# rem (remainder when divided by 2):
#  [[1 0]
#  [0 1]
#  [1 1]]
#
# round:
#  [[ 9  2]
#  [-8  7]
#  [ 5 -1]]
#
# floor:
#  [[ 9.  2.]
#  [-8.  7.]
#  [ 5. -1.]]
#
# ceil:
#  [[ 9.  2.]
#  [-8.  7.]
#  [ 5. -1.]]
# /tmp/ipykernel_1938/731464363.py:18: RuntimeWarning: invalid value encountered in log
#   log_values = np.log(matrix)  # Natural logarithm (log base e)
# /tmp/ipykernel_1938/731464363.py:22: RuntimeWarning: invalid value encountered in sqrt
#   sqrt_values = np.sqrt(matrix)

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# 2×3 matrix with float values
mat = np.array([
    [2.1, 4.7, 1.5],
    [8.3, 3.2, 6.9]
])

# 1. Maximum value and index of max element
max_value = np.max(mat)
max_index = np.unravel_index(np.argmax(mat), mat.shape)

# 2. Minimum value and index of min element
min_value = np.min(mat)
min_index = np.unravel_index(np.argmin(mat), mat.shape)

# 3. Length of the matrix (total number of elements)
mat_length = mat.size

# 4. Sorting
# Row-wise descending
row_sorted_desc = np.sort(mat, axis=1)[:, ::-1]

# Entire matrix descending
matrix_sorted_desc = np.sort(mat.flatten())[::-1]

# 5. Sum of elements
sum_values = np.sum(mat)

# 6. Product of elements
prod_values = np.prod(mat)

# 7. Median value
median_value = np.median(mat)

# 8. Mean value
mean_value = np.mean(mat)

# 9. Standard deviation
std_dev = np.std(mat)

# Display results
print("Original Matrix:\n", mat)

print("\nMax value:", max_value, "at index", max_index)
print("Min value:", min_value, "at index", min_index)

print("Length of matrix:", mat_length)

print("\nRow-wise descending sort:")
print(row_sorted_desc)

print("\nEntire matrix descending sort:")
print(matrix_sorted_desc)

print("\nSum of elements:", sum_values)
print("Product of elements:", prod_values)

print("Median value:", median_value)
print("Mean value:", mean_value)
print("Standard deviation:", std_dev)
# Out:
# Original Matrix:
#  [[2.1 4.7 1.5]
#  [8.3 3.2 6.9]]
#
# Max value: 8.3 at index (np.int64(1), np.int64(0))
# Min value: 1.5 at index (np.int64(0), np.int64(2))
# Length of matrix: 6
#
# Row-wise descending sort:
# [[4.7 2.1 1.5]
#  [8.3 6.9 3.2]]
#
# Entire matrix descending sort:
# [8.3 6.9 4.7 3.2 2.1 1.5]
#
# Sum of elements: 26.700000000000003
# Product of elements: 2713.2235200000005
# Median value: 3.95
# Mean value: 4.45
# Standard deviation: 2.4723470630152233

# %%
#Bonus
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Random 2×3 matrix with float values (Bonus)
mat = np.random.uniform(1, 10, (2, 3))

# 1. Maximum value and index of max element
max_value = np.max(mat)
max_index = np.unravel_index(np.argmax(mat), mat.shape)

# 2. Minimum value and index of min element
min_value = np.min(mat)
min_index = np.unravel_index(np.argmin(mat), mat.shape)

# 3. Length of the matrix (total number of elements)
mat_length = mat.size

# 4. Sorting
# Row-wise descending
row_sorted_desc = np.sort(mat, axis=1)[:, ::-1]

# Entire matrix descending
matrix_sorted_desc = np.sort(mat.flatten())[::-1]

# 5. Sum of elements
sum_values = np.sum(mat)

# 6. Product of elements
prod_values = np.prod(mat)

# 7. Median value
median_value = np.median(mat)

# 8. Mean value
mean_value = np.mean(mat)

# 9. Standard deviation
std_dev = np.std(mat)

# Display results
print("Random Matrix:\n", mat)

print("\nMax value:", max_value, "at index", max_index)
print("Min value:", min_value, "at index", min_index)

print("Length of matrix:", mat_length)

print("\nRow-wise descending sort:")
print(row_sorted_desc)

print("\nEntire matrix descending sort:")
print(matrix_sorted_desc)

print("\nSum of elements:", sum_values)
print("Product of elements:", prod_values)

print("Median value:", median_value)
print("Mean value:", mean_value)
print("Standard deviation:", std_dev)

# Bonus: Heatmap Visualization
plt.figure(figsize=(5, 3))
sns.heatmap(mat, annot=True, cmap="viridis")

plt.title("2×3 Matrix Heatmap")
plt.show()
# Out:
# Random Matrix:
#  [[3.66447926 6.73138442 3.82171206]
#  [4.58042264 6.82882542 5.67337537]]
#
# Max value: 6.8288254248753875 at index (np.int64(1), np.int64(1))
# Min value: 3.6644792579882637 at index (np.int64(0), np.int64(0))
# Length of matrix: 6
#
# Row-wise descending sort:
# [[6.73138442 3.82171206 3.66447926]
#  [6.82882542 5.67337537 4.58042264]]
#
# Entire matrix descending sort:
# [6.82882542 6.73138442 5.67337537 4.58042264 3.82171206 3.66447926]
#
# Sum of elements: 31.300199165254995
# Product of elements: 16728.91232142252
# Median value: 5.12689900502842
# Mean value: 5.216699860875832
# Standard deviation: 1.2820555855546636
